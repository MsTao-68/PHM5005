# %%
import pandas as pd

RNAseq_df = pd.read_csv('/Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/gene.csv', sep=',', header=0)
RNAseq_df.head()
# Out:
#        ID_REF  1007_s_at   1053_at     117_at    121_at  1255_g_at    1294_at  \
# 0  GSM1682614   492.5000   988.500  1677.0000  2856.200  197.50000   3948.200
# 1  GSM1682615   992.2914  1671.248   312.9964  1514.233   68.79980   6455.948
# 2  GSM1682616   639.9207  2475.515   369.9277  2167.405   93.66864  10215.440
# 3  GSM1682617  1586.2420  1669.516   395.1871  1687.894  137.29080   4501.796
# 4  GSM1682618   673.6545  2246.731   857.8096  1973.064   83.86870   5533.674
#
#     1316_at    1320_at  1405_i_at  ...  206927_s_at  206928_at  206929_s_at  \
# 0  749.4000  216.50000   1561.100  ...    136.00000   3003.800     489.8000
# 1  585.3797   33.89514   1053.610  ...    190.01090   4108.014    1030.2210
# 2  682.4297   50.10245   6135.089  ...    330.32360   5128.173    1402.8630
# 3  403.4219   18.10369  19350.590  ...    367.85490   5427.443     807.0797
# 4  530.7810   32.94907  12308.010  ...     18.18558   2551.292    1081.4950
#
#    206930_at  206931_at  206932_at  206933_s_at  206934_at  206935_at  \
# 0  379.60000   945.8000  102.70000     95.00000  1124.5000   91.40000
# 1  109.02470   767.2295   11.72884    173.57690   169.2777    5.28214
# 2  195.03890   331.0485  101.89820    207.26920   245.7526   46.15807
# 3   73.01001   926.1743  230.80090    119.15180   195.9008   13.60067
# 4  219.95090   371.7992  177.03040     21.19365  1220.5080  192.27200
#
#    206936_x_at
# 0     2573.400
# 1     1985.431
# 2     3002.954
# 3     2641.230
# 4     1311.488
#
# [5 rows x 16384 columns]

# %%
annotation_df = pd.read_csv("/Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/gene_annotation.csv")
annotation_df.head()
# Out:
# /var/folders/yt/4vt30kl954v6sbkyllrk4g_80000gn/T/ipykernel_59247/74800877.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   annotation_df = pd.read_csv("/Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/gene_annotation.csv")
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...

# %%
# transpose RNAseq_df for probe IDs become rows
transposed_RNAseq_df = RNAseq_df.set_index('ID_REF').T

# merge operation using probe IDs as keys
merged_RNAseq_df = transposed_RNAseq_df.merge(annotation_df[['ID', 'Gene Symbol']], left_index=True, right_on='ID', how='left')

# set Gene Symbol as index, drop gene_annotation ID column and rename Gene Symbol to ID
merged_RNAseq_df.set_index('Gene Symbol', inplace=True)
merged_RNAseq_df.drop('ID', axis=1, inplace=True)
merged_RNAseq_df.index.name = 'ID_REF'
# transpose back to original format
annotated_RNAseq_df = merged_RNAseq_df.T

annotated_RNAseq_df.head()
# Out:
# ID_REF      DDR1 /// MIR4640      RFC2      HSPA6      PAX8     GUCA1A  \
# GSM1682614          492.5000   988.500  1677.0000  2856.200  197.50000
# GSM1682615          992.2914  1671.248   312.9964  1514.233   68.79980
# GSM1682616          639.9207  2475.515   369.9277  2167.405   93.66864
# GSM1682617         1586.2420  1669.516   395.1871  1687.894  137.29080
# GSM1682618          673.6545  2246.731   857.8096  1973.064   83.86870
#
# ID_REF      MIR5193 /// UBA7      THRA     PTPN21       CCL5    CYP2E1  ...  \
# GSM1682614          3948.200  749.4000  216.50000   1561.100  117.1000  ...
# GSM1682615          6455.948  585.3797   33.89514   1053.610  278.7386  ...
# GSM1682616         10215.440  682.4297   50.10245   6135.089  316.6735  ...
# GSM1682617          4501.796  403.4219   18.10369  19350.590  177.1738  ...
# GSM1682618          5533.674  530.7810   32.94907  12308.010  256.1002  ...
#
# ID_REF        GUCY1A2    ZNF124       NFIC      GLYAT    ZNF141      CH25H  \
# GSM1682614  136.00000  3003.800   489.8000  379.60000  945.8000  102.70000
# GSM1682615  190.01090  4108.014  1030.2210  109.02470  767.2295   11.72884
# GSM1682616  330.32360  5128.173  1402.8630  195.03890  331.0485  101.89820
# GSM1682617  367.85490  5427.443   807.0797   73.01001  926.1743  230.80090
# GSM1682618   18.18558  2551.292  1081.4950  219.95090  371.7992  177.03040
#
# ID_REF           H6PD     SIRPB1      PCDH8       NaN
# GSM1682614   95.00000  1124.5000   91.40000  2573.400
# GSM1682615  173.57690   169.2777    5.28214  1985.431
# GSM1682616  207.26920   245.7526   46.15807  3002.954
# GSM1682617  119.15180   195.9008   13.60067  2641.230
# GSM1682618   21.19365  1220.5080  192.27200  1311.488
#
# [5 rows x 16383 columns]

# %%
# drop NaN columns from df
columns_to_drop = annotated_RNAseq_df.columns[pd.isnull(annotated_RNAseq_df.columns)]
Final_annotated_RNAseq_df = annotated_RNAseq_df.drop(columns_to_drop, axis=1)

# split each column name on '///', keep the first part, and strip any leading/trailing spaces (clean up of column headers)
Final_annotated_RNAseq_df.columns = [name.split('///')[0].strip() for name in Final_annotated_RNAseq_df.columns]

#print(Final_annotated_RNAseq_df.columns)
print(Final_annotated_RNAseq_df.head())
# Out:
#                  DDR1      RFC2      HSPA6      PAX8     GUCA1A    MIR5193  \
# GSM1682614   492.5000   988.500  1677.0000  2856.200  197.50000   3948.200
# GSM1682615   992.2914  1671.248   312.9964  1514.233   68.79980   6455.948
# GSM1682616   639.9207  2475.515   369.9277  2167.405   93.66864  10215.440
# GSM1682617  1586.2420  1669.516   395.1871  1687.894  137.29080   4501.796
# GSM1682618   673.6545  2246.731   857.8096  1973.064   83.86870   5533.674
#
#                 THRA     PTPN21       CCL5    CYP2E1  ...       IL11  \
# GSM1682614  749.4000  216.50000   1561.100  117.1000  ...  182.20000
# GSM1682615  585.3797   33.89514   1053.610  278.7386  ...  410.95720
# GSM1682616  682.4297   50.10245   6135.089  316.6735  ...  173.86440
# GSM1682617  403.4219   18.10369  19350.590  177.1738  ...  251.78640
# GSM1682618  530.7810   32.94907  12308.010  256.1002  ...   99.94088
#
#               GUCY1A2    ZNF124       NFIC      GLYAT    ZNF141      CH25H  \
# GSM1682614  136.00000  3003.800   489.8000  379.60000  945.8000  102.70000
# GSM1682615  190.01090  4108.014  1030.2210  109.02470  767.2295   11.72884
# GSM1682616  330.32360  5128.173  1402.8630  195.03890  331.0485  101.89820
# GSM1682617  367.85490  5427.443   807.0797   73.01001  926.1743  230.80090
# GSM1682618   18.18558  2551.292  1081.4950  219.95090  371.7992  177.03040
#
#                  H6PD     SIRPB1      PCDH8
# GSM1682614   95.00000  1124.5000   91.40000
# GSM1682615  173.57690   169.2777    5.28214
# GSM1682616  207.26920   245.7526   46.15807
# GSM1682617  119.15180   195.9008   13.60067
# GSM1682618   21.19365  1220.5080  192.27200
#
# [5 rows x 14079 columns]

# %% [markdown]
# #### microarray product infosheet
#
# -> houskeeping genes; GAPDH
#
# https://www.cancer.gov/ccg/research/structural-genomics/tcga/using-tcga-data/technology/affymetrix-u133-data-sheet
#
# #### Normalisation method
#
# -> quantile adjustment methods widely used
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3087835/

# %%
cohort = pd.read_csv("/Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/cohort.csv")
cohort.head()
# Out:
#        ID_REF  AGE SUBTYPES GENDER
# 0  GSM1682614   56       M1      M
# 1  GSM1682615   43       M1      F
# 2  GSM1682616   45       M2      F
# 3  GSM1682617   70       M1      F
# 4  GSM1682618   62       M5      M

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# order of the subtypes
subtype_order = ['M0', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'Not Classified']

# hist
sns.countplot(data=cohort, x='SUBTYPES', order=subtype_order, palette='coolwarm' )
plt.title('Distribution of Subtypes')
plt.xlabel('Subtype')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate labels to make them readable if necessary
plt.show()
# Out:
# /var/folders/yt/4vt30kl954v6sbkyllrk4g_80000gn/T/ipykernel_59247/632685394.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=cohort, x='SUBTYPES', order=subtype_order, palette='coolwarm' )

# %%
# filter out rows where 'SUBTYPES' column is 'Not classified'
cohort_filtered = cohort.loc[cohort['SUBTYPES'] != 'Not classified']

# Display the filtered DataFrame
print(cohort_filtered)
# Out:
#          ID_REF  AGE SUBTYPES GENDER
# 0    GSM1682614   56       M1      M
# 1    GSM1682615   43       M1      F
# 2    GSM1682616   45       M2      F
# 3    GSM1682617   70       M1      F
# 4    GSM1682618   62       M5      M
# ..          ...  ...      ...    ...
# 178  GSM1682792   25       M2      M
# 179  GSM1682793   33       M3      M
# 180  GSM1682794   50       M6      M
# 181  GSM1682795   48       M3      M
# 182  GSM1682796   54       M1      F
#
# [181 rows x 4 columns]

# %%
# merging subtypes from cohort df to transposed RNA_seq_df
AML_subtype_df = Final_annotated_RNAseq_df.merge(cohort[['ID_REF','SUBTYPES']], left_index=True, right_on='ID_REF', how='left')

#fix for issue with column indexing
columns = ['ID_REF', 'SUBTYPES'] + [col for col in AML_subtype_df.columns if col not in ['ID_REF', 'SUBTYPES']]
AML_subtype_df = AML_subtype_df[columns]


AML_subtype_df.head()

#print(AML_subtype_df.columns)
# Out:
#        ID_REF SUBTYPES       DDR1      RFC2      RFC2      HSPA6      PAX8  \
# 0  GSM1682614       M1   492.5000   988.500  1522.300  1677.0000  2856.200
# 1  GSM1682615       M1   992.2914  1671.248  1205.765   312.9964  1514.233
# 2  GSM1682616       M2   639.9207  2475.515  2045.759   369.9277  2167.405
# 3  GSM1682617       M1  1586.2420  1669.516  3182.640   395.1871  1687.894
# 4  GSM1682618       M5   673.6545  2246.731  2588.312   857.8096  1973.064
#
#       GUCA1A     GUCA1A    MIR5193  ...    ZNF124       NFIC      GLYAT  \
# 0  197.50000  236.20000   3948.200  ...  3003.800   489.8000  379.60000
# 1   68.79980  179.45170   6455.948  ...  4108.014  1030.2210  109.02470
# 2   93.66864  199.04000  10215.440  ...  5128.173  1402.8630  195.03890
# 3  137.29080   93.24465   4501.796  ...  5427.443   807.0797   73.01001
# 4   83.86870  343.66590   5533.674  ...  2551.292  1081.4950  219.95090
#
#      ZNF141      CH25H      H6PD       H6PD     SIRPB1     SIRPB1      PCDH8
# 0  945.8000  102.70000   60.7000   95.00000  2096.0000  1124.5000   91.40000
# 1  767.2295   11.72884  274.0456  173.57690   126.5837   169.2777    5.28214
# 2  331.0485  101.89820  615.4205  207.26920   728.1829   245.7526   46.15807
# 3  926.1743  230.80090  327.4015  119.15180   595.7837   195.9008   13.60067
# 4  371.7992  177.03040  150.9986   21.19365  4153.4330  1220.5080  192.27200
#
# [5 rows x 24937 columns]

# %%
#encoding the subtypes
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
AML_subtype_df['SUBTYPES'] = label_encoder.fit_transform(AML_subtype_df['SUBTYPES'])
AML_subtype_df.head()
# Out:
#        ID_REF  SUBTYPES       DDR1      RFC2      RFC2      HSPA6      PAX8  \
# 0  GSM1682614         1   492.5000   988.500  1522.300  1677.0000  2856.200
# 1  GSM1682615         1   992.2914  1671.248  1205.765   312.9964  1514.233
# 2  GSM1682616         2   639.9207  2475.515  2045.759   369.9277  2167.405
# 3  GSM1682617         1  1586.2420  1669.516  3182.640   395.1871  1687.894
# 4  GSM1682618         5   673.6545  2246.731  2588.312   857.8096  1973.064
#
#       GUCA1A     GUCA1A    MIR5193  ...    ZNF124       NFIC      GLYAT  \
# 0  197.50000  236.20000   3948.200  ...  3003.800   489.8000  379.60000
# 1   68.79980  179.45170   6455.948  ...  4108.014  1030.2210  109.02470
# 2   93.66864  199.04000  10215.440  ...  5128.173  1402.8630  195.03890
# 3  137.29080   93.24465   4501.796  ...  5427.443   807.0797   73.01001
# 4   83.86870  343.66590   5533.674  ...  2551.292  1081.4950  219.95090
#
#      ZNF141      CH25H      H6PD       H6PD     SIRPB1     SIRPB1      PCDH8
# 0  945.8000  102.70000   60.7000   95.00000  2096.0000  1124.5000   91.40000
# 1  767.2295   11.72884  274.0456  173.57690   126.5837   169.2777    5.28214
# 2  331.0485  101.89820  615.4205  207.26920   728.1829   245.7526   46.15807
# 3  926.1743  230.80090  327.4015  119.15180   595.7837   195.9008   13.60067
# 4  371.7992  177.03040  150.9986   21.19365  4153.4330  1220.5080  192.27200
#
# [5 rows x 24937 columns]

# %%
AML_subtype_df.to_csv("//Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/AML.csv", index=False)

# %%
aml_RNAseq = pd.read_csv("/Users/keerthana/Documents/NUS Precision Med 25/5005/5005_Project/Processed Datasets/AML.csv")

# sample first 3 gene expression (features) for visualization
sample_features = aml_RNAseq.columns[2:5]

# plots for distribution of selected features
for feature in sample_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(aml_RNAseq[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Applying log1p transformation, which is log(x + 1), to avoid log(0)
log_transformed_RNAseq = np.log1p(aml_RNAseq[sample_features])

# Visualize the transformed data
for feature in sample_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(log_transformed_RNAseq[feature], kde=True)
    plt.title(f'Log Transformed Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Applying log1p transformation, which is log(x + 1), to avoid log(0)
# ----> 2 log_transformed_RNAseq = np.log1p(aml_RNAseq[sample_features])
#       4 # Visualize the transformed data
#       5 for feature in sample_features:
#
# NameError: name 'np' is not defined

# %%
#from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler()
#scaled_RNAseq = scaler.fit_transform(aml_RNAseq[sample_features])

# Convert back to DataFrame for easy plotting
#scaled_RNAseq = pd.DataFrame(scaled_RNAseq, columns=sample_features)

# Visualize the standardized data
#for feature in sample_features:
    #plt.figure(figsize=(10, 6))
    #sns.histplot(scaled_RNAseq[feature], kde=True)
    #plt.title(f'Standardized Distribution of {feature}')
    #plt.xlabel(feature)
    #plt.ylabel('Frequency')
    #plt.show()

# %% [markdown]
# ##### Chose log transformation to normalise the data based on above plots

# %%
import numpy as np
# Apply log transformation to all feature columns except 'ID_REF' and 'SUBTYPES'
features = aml_RNAseq.drop(['ID_REF', 'SUBTYPES'], axis=1)
df_log_transformed = np.log1p(features)

# Now, let's include the non-feature columns back for a complete dataset
df_log_transformed['ID_REF'] = aml_RNAseq['ID_REF']
df_log_transformed['SUBTYPES'] = aml_RNAseq['SUBTYPES']

for feature in sample_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df_log_transformed[feature], kde=True)
    plt.title(f'Log Transformed Distribution of {feature}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)  # Retain 95% of variance
features_pca = pca.fit_transform(df_log_transformed.drop(['ID_REF', 'SUBTYPES'], axis=1))

# Visualize PCA results
plt.figure(figsize=(10, 6))
sns.scatterplot(x=features_pca[:, 0], y=features_pca[:, 1], hue=df_log_transformed['SUBTYPES'])
plt.title('PCA of Log Transformed Gene Expression Data')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Subtype', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=features_pca[:, 2], y=features_pca[:, 3], hue=df_log_transformed['SUBTYPES'], palette='viridis')
plt.title('PCA of Gene Expression Data - Components 3 and 4')
plt.xlabel('PCA Component 3')
plt.ylabel('PCA Component 4')
plt.legend(title='Subtype', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a PCA result stored in `features_pca`
# and the subtype labels stored in `df['SUBTYPES']`

# Initialize t-SNE
tsne = TSNE(n_components=2, random_state=42)

# Apply t-SNE to the PCA-reduced data
# This step can take some time because t-SNE is computationally intensive
tsne_results = tsne.fit_transform(features_pca)

# Plot the t-SNE results
plt.figure(figsize=(12, 8))
sns.scatterplot(
    x=tsne_results[:, 0], y=tsne_results[:, 1], 
    hue=df_log_transformed['SUBTYPES'], # Make sure you have your subtype labels for coloring
    palette=sns.color_palette("hsv", len(np.unique(df_log_transformed['SUBTYPES']))), # Adjust the palette based on your number of subtypes
    legend="full"
)

plt.title('t-SNE Visualization of PCA-Reduced Gene Expression Data')
plt.xlabel('t-SNE Axis 1')
plt.ylabel('t-SNE Axis 2')
plt.legend(title='Subtype', loc='best')
plt.show()

# %%
# First, let's drop the non-numeric columns if not already done
#df_numeric = AML_subtype_df.drop(['ID_REF', 'SUBTYPES'], axis=1)

# Identify incomplete and complete rows
#mask_complete = (~df_numeric.isnull()).all(axis=1)
#mask_incomplete = df_numeric.isnull().any(axis=1)

#complete_genes = AML_subtype_df[mask_complete]
#incomplete_genes = AML_subtype_df[mask_incomplete]

#complete_genes.head()
#incomplete_genes.head()
# complete_genes contains rows without any missing values.
# incomplete_genes contains rows with one or more missing values -> there is none

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
import numpy as np

features_complete = complete_genes.drop(['ID_REF', 'SUBTYPES'], axis=1)

# Scale your features
scaler = StandardScaler()
features_complete_scaled = scaler.fit_transform(features_complete)

def calculate_dvindex(n_clusters, data_scaled):
    if n_clusters == 1:
        return np.inf  # Can't properly calculate DVIndex for a single cluster
    
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(data_scaled)
    labels = kmeans.labels_
    cluster_centers = kmeans.cluster_centers_
    
    intra_distances = pairwise_distances(data_scaled, cluster_centers[labels], metric='euclidean')
    intra_compactness = np.mean(np.min(intra_distances, axis=1))
    
    if n_clusters > 1:
        inter_distances = pairwise_distances(cluster_centers, metric='euclidean')
        np.fill_diagonal(inter_distances, np.inf)  # Ignore zero distance to itself
        inter_separation = np.min(inter_distances)
    else:
        inter_separation = np.inf  # Undefined for a single cluster
    
    dv_index = intra_compactness / inter_separation
    return dv_index

# Determine the optimal number of clusters based on DVIndex
dvindex_values = []
max_clusters = 20  # You might adjust this based on your data and needs

for k in range(1, max_clusters + 1):
    dv_index = calculate_dvindex(k, features_complete_scaled)
    dvindex_values.append(dv_index)

optimal_clusters = np.argmin(dvindex_values) + 1  # +1 because of zero-based index offset
print(f"Optimal number of clusters: {optimal_clusters}")

# Final clustering with the optimal number of clusters
kmeans_final = KMeans(n_clusters=optimal_clusters, random_state=42).fit(features_scaled)
complete_genes['Cluster'] = kmeans_final.labels_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       8 # Scale your features
#       9 scaler = StandardScaler()
# ---> 10 features_complete_scaled = scaler.fit_transform(features_complete)
#      12 def calculate_dvindex(n_clusters, data_scaled):
#      13     if n_clusters == 1:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
#     277             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     278             *data_to_wrap[1:],
#     279         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:1061, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1046         warnings.warn(
#    1047             (
#    1048                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1056             UserWarning,
#    1057         )
#    1059 if y is None:
#    1060     # fit method of arity 1 (unsupervised transformation)
# -> 1061     return self.fit(X, **fit_params).transform(X)
#    1062 else:
#    1063     # fit method of arity 2 (supervised transformation)
#    1064     return self.fit(X, y, **fit_params).transform(X)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:876, in StandardScaler.fit(self, X, y, sample_weight)
#     874 # Reset internal state before fitting
#     875 self._reset()
# --> 876 return self.partial_fit(X, y, sample_weight)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:912, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     880 """Online computation of mean and std on X for later scaling.
#     881
#     882 All of X is processed as a single batch. This is intended for cases
#    (...)
#     909     Fitted scaler.
#     910 """
#     911 first_call = not hasattr(self, "n_samples_seen_")
# --> 912 X = self._validate_data(
#     913     X,
#     914     accept_sparse=("csr", "csc"),
#     915     dtype=FLOAT_DTYPES,
#     916     force_all_finite="allow-nan",
#     917     reset=first_call,
#     918 )
#     919 n_features = X.shape[1]
#     921 if sample_weight is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:469, in BaseEstimator._check_feature_names(self, X, reset)
#     449 """Set or check the `feature_names_in_` attribute.
#     450
#     451 .. versionadded:: 1.0
#    (...)
#     465        should set `reset=False`.
#     466 """
#     468 if reset:
# --> 469     feature_names_in = _get_feature_names(X)
#     470     if feature_names_in is not None:
#     471         self.feature_names_in_ = feature_names_in
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:2142, in _get_feature_names(X)
#    2140 # mixed type of string and non-string is not supported
#    2141 if len(types) > 1 and "str" in types:
# -> 2142     raise TypeError(
#    2143         "Feature names are only supported if all input features have string names, "
#    2144         f"but your input has {types} as feature name / column name types. "
#    2145         "If you want feature names to be stored and validated, you must convert "
#    2146         "them all to strings, by using X.columns = X.columns.astype(str) for "
#    2147         "example. Otherwise you can remove feature / column names from your input "
#    2148         "data, or convert them all to a non-string data type."
#    2149     )
#    2151 # Only feature names of all strings are supported
#    2152 if len(types) == 1 and types[0] == "str":
#
# TypeError: Feature names are only supported if all input features have string names, but your input has ['float', 'str'] as feature name / column name types. If you want feature names to be stored and validated, you must convert them all to strings, by using X.columns = X.columns.astype(str) for example. Otherwise you can remove feature / column names from your input data, or convert them all to a non-string data type.

# %%
# Perform spectral clustering
sc = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors', n_neighbors=10, random_state=0)
clusters_complete = sc.fit_predict(features_complete_scaled)

# Add cluster labels to the complete_genes DataFrame
complete_genes['Cluster'] = clusters_complete
